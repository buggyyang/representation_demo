# %%
# %matplotlib inline
from src.render import *
# Out:
# /Users/rhyang/miniconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence

# %%
render_pitch()
# Out:
# interactive(children=(IntSlider(value=5, description='idx', max=11), Output(layout=Layout(height='400px'))), _…

# %%
render_pitch_sort()

# %%
render_rhythm()
# Out:
# interactive(children=(IntSlider(value=1, description='idx', max=3), Output(layout=Layout(height='400px'))), _d…

# %%
render_rhythm_sort()

# %%
render_samples()

# %%
load_samples()

# %%
render_adjust_pitch()

# %%
render_adjust_rhythm()

# %%
render_adjust_rest()

# %%
render_interpolation()
